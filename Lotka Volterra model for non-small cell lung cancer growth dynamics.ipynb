# %%
using Pkg
Pkg.add("DifferentialEquations")
# Out:
#     Updating registry at `C:\Users\Juan Martinez\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed NonlinearSolve ─────────────────── v0.3.22
#    Installed TreeViews ──────────────────────── v0.3.0
#    Installed OffsetArrays ───────────────────── v1.12.7
#    Installed Calculus ───────────────────────── v0.5.1
#    Installed HypergeometricFunctions ────────── v0.3.11
#    Installed StatsFuns ──────────────────────── v1.0.1
#    Installed SIMDDualNumbers ────────────────── v0.1.1
#    Installed DifferentialEquations ──────────── v7.5.0
#    Installed PDMats ─────────────────────────── v0.11.16
#    Installed Sundials_jll ───────────────────── v5.2.1+0
#    Installed FunctionWrappers ───────────────── v1.1.3
#    Installed Polyester ──────────────────────── v0.6.16
#    Installed TriangularSolve ────────────────── v0.1.14
#    Installed RecursiveArrayTools ────────────── v2.32.0
#    Installed StaticArrays ───────────────────── v1.5.9
#    Installed RandomNumbers ──────────────────── v1.5.3
#    Installed ArrayInterfaceOffsetArrays ─────── v0.1.6
#    Installed ZygoteRules ────────────────────── v0.2.2
#    Installed CEnum ──────────────────────────── v0.4.2
#    Installed Distances ──────────────────────── v0.10.7
#    Installed Static ─────────────────────────── v0.7.7
#    Installed SLEEFPirates ───────────────────── v0.6.36
#    Installed BoundaryValueDiffEq ────────────── v2.9.0
#    Installed FiniteDiff ─────────────────────── v2.15.0
#    Installed Missings ───────────────────────── v1.0.2
#    Installed KrylovKit ──────────────────────── v0.5.4
#    Installed SteadyStateDiffEq ──────────────── v1.9.0
#    Installed IrrationalConstants ────────────── v0.1.1
#    Installed Tricks ─────────────────────────── v0.1.6
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed MuladdMacro ────────────────────── v0.2.2
#    Installed ArnoldiMethod ──────────────────── v0.2.0
#    Installed DiffEqBase ─────────────────────── v6.105.1
#    Installed SciMLBase ──────────────────────── v1.59.5
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed BandedMatrices ─────────────────── v0.17.7
#    Installed SpecialFunctions ───────────────── v2.1.7
#    Installed NLsolve ────────────────────────── v4.5.1
#    Installed DiffEqNoiseProcess ─────────────── v5.13.0
#    Installed LinearSolve ────────────────────── v1.26.1
#    Installed ArrayInterfaceGPUArrays ────────── v0.2.2
#    Installed OrdinaryDiffEq ─────────────────── v6.28.0
#    Installed ArrayInterfaceCore ─────────────── v0.1.20
#    Installed StaticArraysCore ───────────────── v1.4.0
#    Installed NaNMath ────────────────────────── v1.0.1
#    Installed ThreadingUtilities ─────────────── v0.5.0
#    Installed SnoopPrecompile ────────────────── v1.0.1
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed JumpProcesses ──────────────────── v9.2.0
#    Installed LevyArea ───────────────────────── v1.0.0
#    Installed NLSolversBase ──────────────────── v7.8.2
#    Installed Random123 ──────────────────────── v1.6.0
#    Installed Rmath_jll ──────────────────────── v0.3.0+0
#    Installed Graphs ─────────────────────────── v1.7.4
#    Installed CommonSubexpressions ───────────── v0.3.0
#    Installed StatsAPI ───────────────────────── v1.5.0
#    Installed Compat ─────────────────────────── v4.3.0
#    Installed ArrayLayouts ───────────────────── v0.8.11
#    Installed DataStructures ─────────────────── v0.18.13
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.4
#    Installed StatsBase ──────────────────────── v0.33.21
#    Installed DiffRules ──────────────────────── v1.11.1
#    Installed GenericSchur ───────────────────── v0.5.3
#    Installed FunctionWrappersWrappers ───────── v0.1.1
#    Installed Inflate ────────────────────────── v0.1.3
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed LayoutPointers ─────────────────── v0.1.10
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed StochasticDiffEq ───────────────── v6.54.0
#    Installed Sundials ───────────────────────── v4.10.1
#    Installed ArrayInterfaceStaticArraysCore ─── v0.1.0
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed DiffEqCallbacks ────────────────── v2.24.1
#    Installed Setfield ───────────────────────── v1.1.1
#    Installed DelayDiffEq ────────────────────── v5.38.0
#    Installed ConstructionBase ───────────────── v1.4.1
#    Installed LoopVectorization ──────────────── v0.12.133
#    Installed FastClosures ───────────────────── v0.3.2
#    Installed OrderedCollections ─────────────── v1.4.1
#    Installed PolyesterWeave ─────────────────── v0.1.10
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed ChainRulesCore ─────────────────── v1.15.6
#    Installed LineSearches ───────────────────── v7.2.0
#    Installed FastLapackInterface ────────────── v1.2.7
#    Installed ArrayInterface ─────────────────── v6.0.23
#    Installed PreallocationTools ─────────────── v0.4.4
#    Installed LogExpFunctions ────────────────── v0.3.18
#    Installed KLU ────────────────────────────── v0.3.0
#    Installed OpenSpecFun_jll ────────────────── v0.5.5+0
#    Installed CloseOpenIntervals ─────────────── v0.1.10
#    Installed Krylov ─────────────────────────── v0.8.4
#    Installed MacroTools ─────────────────────── v0.5.10
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed InverseFunctions ───────────────── v0.1.8
#    Installed ArrayInterfaceStaticArrays ─────── v0.1.4
#    Installed GPUArraysCore ──────────────────── v0.1.2
#    Installed Adapt ──────────────────────────── v3.4.0
#    Installed CommonSolve ────────────────────── v0.2.1
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed DocStringExtensions ────────────── v0.9.1
#    Installed ExponentialUtilities ───────────── v1.19.0
#    Installed DualNumbers ────────────────────── v0.6.8
#    Installed Rmath ──────────────────────────── v0.7.0
#    Installed StrideArraysCore ───────────────── v0.3.15
#    Installed CPUSummary ─────────────────────── v0.1.27
#    Installed Tables ─────────────────────────── v1.9.0
#    Installed VectorizationBase ──────────────── v0.21.51
#    Installed VertexSafeGraphs ───────────────── v0.2.0
#    Installed Optim ──────────────────────────── v1.7.3
#    Installed DataAPI ────────────────────────── v1.12.0
#    Installed RecipesBase ────────────────────── v1.3.0
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed HostCPUFeatures ────────────────── v0.1.8
#    Installed PoissonRandom ──────────────────── v0.4.1
#    Installed IterativeSolvers ───────────────── v0.9.2
#    Installed ForwardDiff ────────────────────── v0.10.32
#    Installed FillArrays ─────────────────────── v0.13.4
#    Installed QuadGK ─────────────────────────── v2.5.0
#    Installed ResettableStacks ───────────────── v1.1.1
#    Installed Requires ───────────────────────── v1.3.0
#    Installed FastBroadcast ──────────────────── v0.2.1
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed RecursiveFactorization ─────────── v0.2.12
#    Installed SortingAlgorithms ──────────────── v1.0.1
#    Installed ChangesOfVariables ─────────────── v0.1.4
#    Installed SparseDiffTools ────────────────── v1.27.0
#    Installed DensityInterface ───────────────── v0.4.0
#    Installed Distributions ──────────────────── v0.25.75
#     Updating `C:\Users\Juan Martinez\.julia\environments\v1.8\Project.toml`
#   [0c46a032] + DifferentialEquations v7.5.0
#     Updating `C:\Users\Juan Martinez\.julia\environments\v1.8\Manifest.toml`
#   [79e6a3ab] + Adapt v3.4.0
#   [ec485272] + ArnoldiMethod v0.2.0
#   [4fba245c] + ArrayInterface v6.0.23
#   [30b0a656] + ArrayInterfaceCore v0.1.20
#   [6ba088a2] + ArrayInterfaceGPUArrays v0.2.2
#   [015c0d05] + ArrayInterfaceOffsetArrays v0.1.6
#   [b0d46f97] + ArrayInterfaceStaticArrays v0.1.4
#   [dd5226c6] + ArrayInterfaceStaticArraysCore v0.1.0
#   [4c555306] + ArrayLayouts v0.8.11
#   [aae01518] + BandedMatrices v0.17.7
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.4
#   [764a87c0] + BoundaryValueDiffEq v2.9.0
#   [fa961155] + CEnum v0.4.2
#   [2a0fbf3d] + CPUSummary v0.1.27
#   [49dc2e85] + Calculus v0.5.1
#   [d360d2e6] + ChainRulesCore v1.15.6
#   [9e997f8a] + ChangesOfVariables v0.1.4
#   [fb6a15b2] + CloseOpenIntervals v0.1.10
#   [38540f10] + CommonSolve v0.2.1
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.3.0
#   [187b0558] + ConstructionBase v1.4.1
#   [adafc99b] + CpuId v0.3.1
#   [9a962f9c] + DataAPI v1.12.0
#   [864edb3b] + DataStructures v0.18.13
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [bcd4f6db] + DelayDiffEq v5.38.0
#   [b429d917] + DensityInterface v0.4.0
#   [2b5f629d] + DiffEqBase v6.105.1
#   [459566f4] + DiffEqCallbacks v2.24.1
#   [77a26b50] + DiffEqNoiseProcess v5.13.0
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.11.1
#   [0c46a032] + DifferentialEquations v7.5.0
#   [b4f34e82] + Distances v0.10.7
#   [31c24e10] + Distributions v0.25.75
#   [ffbed154] + DocStringExtensions v0.9.1
#   [fa6b7ba4] + DualNumbers v0.6.8
#   [d4d017d3] + ExponentialUtilities v1.19.0
#   [7034ab61] + FastBroadcast v0.2.1
#   [9aa1b823] + FastClosures v0.3.2
#   [29a986be] + FastLapackInterface v1.2.7
#   [1a297f60] + FillArrays v0.13.4
#   [6a86dc24] + FiniteDiff v2.15.0
#   [f6369f11] + ForwardDiff v0.10.32
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.1
#   [46192b85] + GPUArraysCore v0.1.2
#   [c145ed77] + GenericSchur v0.5.3
#   [86223c79] + Graphs v1.7.4
#   [3e5b6fbb] + HostCPUFeatures v0.1.8
#   [34004b35] + HypergeometricFunctions v0.3.11
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.3
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.1.1
#   [42fd0dbc] + IterativeSolvers v0.9.2
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [ccbc3e58] + JumpProcesses v9.2.0
# ⌅ [ef3ab10e] + KLU v0.3.0
#   [ba0b0d4f] + Krylov v0.8.4
#   [0b1a1467] + KrylovKit v0.5.4
#   [10f19ff3] + LayoutPointers v0.1.10
#   [2d8b4e74] + LevyArea v1.0.0
#   [d3d80556] + LineSearches v7.2.0
#   [7ed4a6bd] + LinearSolve v1.26.1
#   [2ab3a3ac] + LogExpFunctions v0.3.18
#   [bdcacae8] + LoopVectorization v0.12.133
#   [1914dd2f] + MacroTools v0.5.10
#   [d125e4d3] + ManualMemory v0.1.8
#   [e1d29d7a] + Missings v1.0.2
#   [46d2c3a1] + MuladdMacro v0.2.2
#   [d41bc354] + NLSolversBase v7.8.2
#   [2774e3e8] + NLsolve v4.5.1
#   [77ba4419] + NaNMath v1.0.1
#   [8913a72c] + NonlinearSolve v0.3.22
#   [6fe1bfb0] + OffsetArrays v1.12.7
#   [429524aa] + Optim v1.7.3
#   [bac558e1] + OrderedCollections v1.4.1
#   [1dea7af3] + OrdinaryDiffEq v6.28.0
#   [90014a1f] + PDMats v0.11.16
#   [d96e819e] + Parameters v0.12.3
#   [e409e4f3] + PoissonRandom v0.4.1
#   [f517fe37] + Polyester v0.6.16
#   [1d0040c9] + PolyesterWeave v0.1.10
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.4.4
#   [1fd47b50] + QuadGK v2.5.0
#   [74087812] + Random123 v1.6.0
#   [e6cf234a] + RandomNumbers v1.5.3
#   [3cdcf5f2] + RecipesBase v1.3.0
#   [731186ca] + RecursiveArrayTools v2.32.0
#   [f2c3362d] + RecursiveFactorization v0.2.12
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.0
#   [ae5879a3] + ResettableStacks v1.1.1
#   [79098fc4] + Rmath v0.7.0
#   [3cdde19b] + SIMDDualNumbers v0.1.1
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.36
#   [0bca4576] + SciMLBase v1.59.5
#   [efcf1570] + Setfield v1.1.1
#   [699a6c99] + SimpleTraits v0.9.4
#   [66db9d55] + SnoopPrecompile v1.0.1
#   [a2af1166] + SortingAlgorithms v1.0.1
#   [47a9eef4] + SparseDiffTools v1.27.0
#   [276daf66] + SpecialFunctions v2.1.7
#   [aedffcd0] + Static v0.7.7
#   [90137ffa] + StaticArrays v1.5.9
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [4c63d2b9] + StatsFuns v1.0.1
#   [9672c7b4] + SteadyStateDiffEq v1.9.0
#   [789caeaf] + StochasticDiffEq v6.54.0
#   [7792a7ef] + StrideArraysCore v0.3.15
#   [c3572dad] + Sundials v4.10.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.9.0
#   [8290d209] + ThreadingUtilities v0.5.0
#   [a2a6695c] + TreeViews v0.3.0
#   [d5829a12] + TriangularSolve v0.1.14
#   [410a4b4d] + Tricks v0.1.6
#   [3a884ed6] + UnPack v1.0.2
#   [3d5dd08c] + VectorizationBase v0.21.51
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [700de1a5] + ZygoteRules v0.2.2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] + Rmath_jll v0.3.0+0
#   [fb77eaff] + Sundials_jll v5.2.1+0
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [37e2e46d] + LinearAlgebra
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [4607b0f0] + SuiteSparse
#   [e66e0078] + CompilerSupportLibraries_jll v0.5.2+0
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [bea87d4a] + SuiteSparse_jll v5.10.1+0
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#         Info Packages marked with ⌅ have new versions available but cannot be upgraded. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ SnoopPrecompile
#   ✓ MuladdMacro
#   ✓ PositiveFactorizations
#   ✓ FunctionWrappers
#   ✓ Calculus
#   ✓ IteratorInterfaceExtensions
#   ✓ PDMats
#   ✓ Tricks
#   ✓ StatsAPI
#   ✓ CEnum
#   ✓ UnPack
#   ✓ OpenLibm_jll
#   ✓ FillArrays
#   ✓ InverseFunctions
#   ✓ GenericSchur
#   ✓ CommonSolve
#   ✓ KrylovKit
#   ✓ CompilerSupportLibraries_jll
#   ✓ PoissonRandom
#   ✓ ManualMemory
#   ✓ Compat
#   ✓ DataValueInterfaces
#   ✓ OrderedCollections
#   ✓ Reexport
#   ✓ Requires
#   ✓ SIMDTypes
#   ✓ Krylov
#   ✓ DocStringExtensions
#   ✓ TreeViews
#   ✓ ArrayInterfaceCore
#   ✓ IrrationalConstants
#   ✓ MacroTools
#   ✓ IfElse
#   ✓ Inflate
#   ✓ CpuId
#   ✓ DataAPI
#   ✓ Adapt
#   ✓ FastClosures
#   ✓ ConstructionBase
#   ✓ StaticArraysCore
#   ✓ FunctionWrappersWrappers
#   ✓ TableTraits
#   ✓ Rmath_jll
#   ✓ FastLapackInterface
#   ✓ NaNMath
#   ✓ Distances
#   ✓ OpenBLAS_jll
#   ✓ RecipesBase
#   ✓ DensityInterface
#   ✓ OpenSpecFun_jll
#   ✓ Parameters
#   ✓ ThreadingUtilities
#   ✓ ChainRulesCore
#   ✓ RandomNumbers
#   ✓ CommonSubexpressions
#   ✓ DataStructures
#   ✓ ZygoteRules
#   ✓ Missings
#   ✓ Static
#   ✓ SimpleTraits
#   ✓ GPUArraysCore
#   ✓ DiffResults
#   ✓ ArrayInterfaceStaticArraysCore
#   ✓ ArrayLayouts
#   ✓ OffsetArrays
#   ✓ libblastrampoline_jll
#   ✓ Tables
#   ✓ Setfield
#   ✓ Rmath
#   ✓ ChangesOfVariables
#   ✓ SortingAlgorithms
#   ✓ Random123
#   ✓ IterativeSolvers
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ ArrayInterfaceGPUArrays
#   ✓ QuadGK
#   ✓ SuiteSparse_jll
#   ✓ CPUSummary
#   ✓ ArrayInterface
#   ✓ ExponentialUtilities
#   ✓ HostCPUFeatures
#   ✓ LogExpFunctions
#   ✓ KLU
#   ✓ RecursiveArrayTools
#   ✓ Sundials_jll
#   ✓ StaticArrays
#   ✓ BandedMatrices
#   ✓ PolyesterWeave
#   ✓ CloseOpenIntervals
#   ✓ ArrayInterfaceOffsetArrays
#   ✓ ArrayInterfaceStaticArrays
#   ✓ StatsBase
#   ✓ ArnoldiMethod
#   ✓ ResettableStacks
#   ✓ SpecialFunctions
#   ✓ FiniteDiff
#   ✓ LayoutPointers
#   ✓ SciMLBase
#   ✓ LevyArea
#   ✓ DualNumbers
#   ✓ DiffRules
#   ✓ HypergeometricFunctions
#   ✓ StrideArraysCore
#   ✓ Graphs
#   ✓ StatsFuns
#   ✓ ForwardDiff
#   ✓ Polyester
#   ✓ VertexSafeGraphs
#   ✓ PreallocationTools
#   ✓ NLSolversBase
#   ✓ FastBroadcast
#   ✓ SparseDiffTools
#   ✓ Distributions
#   ✓ LineSearches
#   ✓ NLsolve
#   ✓ Optim
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ SIMDDualNumbers
#   ✓ LoopVectorization
#   ✓ TriangularSolve
#   ✓ RecursiveFactorization
#   ✓ NonlinearSolve
#   ✓ DiffEqBase
#   ✓ LinearSolve
#   ✓ DiffEqCallbacks
#   ✓ JumpProcesses
#   ✓ DiffEqNoiseProcess
#   ✓ BoundaryValueDiffEq
#   ✓ SteadyStateDiffEq
#   ✓ Sundials
#   ✓ OrdinaryDiffEq
#   ✓ DelayDiffEq
#   ✓ StochasticDiffEq
#   ✓ DifferentialEquations
#   135 dependencies successfully precompiled in 753 seconds. 15 already precompiled.

# %%
function lotka_volterra!(dx, x, g, p, t)
    # x is a vector of the densities of the cell lines in the model
  
  i1, i2, r, s  = x
    
        # i1 are the anti-oncogenic cells. These cells are T cells and helper T cells 
        #i2 are the pro-oncogenic cells. These cells are Regulatory T cells, macrophages, and myeloid-derived suppressor cells. 
        #r are cancer cells resistant to treatment.
        #s are cancer cells sensitive to treatment.

    # g are the instrinsic growth rates of the cells
    
 g1,g2,gr,gs = g
        #g1 is the anti-oncogenic cells intrinsic growth rate.
        #g2 is the pro-oncogenic cells intrinsic growth rate.  
        #gr is the intrinsic growth rate of the resistant cancer cells.
        #gs is the intrinsic growth rat of the sensitive cancer cells.
    
    # p is the in the interaction coefficients matrix, 
    # the i subscript describes the row where the coefficient  is located in the matrix, 
    # and the j subscript denotes the column of the matrix. Each, row and column correspond 
    # to a species interaction. Where the order of the row and columns of matrix is i1, i2, r, and s
    #For example, the alpha 1,2 is the interaction antioncogenic 
    #cells have on the pro-oncogenic cells.
    
  α1_1, α1_2, α1_3, α1_4 ; α2_1, α2_2, α2_3, α2_4; α3_1, α3_2, α3_3, α3_4; α4_1, α4_2, α4_3, α4_4 = p
    
  dx[1] = di1 = g1*i1 + (i2*α1_1 + i2*α1_2 + r*α1_3 + s*α1_4) 
  dx[2] = di2 = g2*i2 + (i2*α2_1 + i2*α2_2 + r*α2_3 + s*α2_4)
  dx[3] = dr  = g3*r  + (i2*α3_1 + i2*α3_2 + r*α3_3 + s*α3_4)
  du[4] = ds  = g4*s  + (i2*α4_1 + i2*α4_2 + r*α4_3 + s*α4_4)
  nothing
end
# Out:
# lotka_volterra! (generic function with 1 method)
